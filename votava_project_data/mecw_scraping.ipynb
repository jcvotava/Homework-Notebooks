# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
import lucem_illud #just in case, regularly update your lucem_illud with the following code: pip install git+git://github.com/UChicago-Computational-Content-Analysis/lucem_illud.git

#All these packages need to be installed from pip
import requests #for http requests
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import numpy as np #For divergences/distances
import scipy #For divergences/distances
import seaborn as sns #makes our plots look nicer
import sklearn.manifold #For a manifold plot
import json #For API responses
import urllib.parse #For joining urls

# comp-linguistics
import spacy

#Displays the graphs
import graphviz #You also need to install the command line graphviz

#These are from the standard library
import os.path
import zipfile
import subprocess
import io
import tempfile

import wordcloud #Makes word clouds

#All these packages need to be installed from pip
import requests #for http requests
import bs4 #called `beautifulsoup4`, an html parser
import pandas #gives us DataFrames
import docx #reading MS doc files, install as `python-docx`

#Stuff for pdfs
#Install as `pdfminer2`
import pdfminer.pdfinterp
import pdfminer.converter
import pdfminer.layout
import pdfminer.pdfpage

#These come with Python
import re #for regexs
import urllib.parse #For joining urls
import io #for making http requests look like files
import json #For Tumblr API responses
import os.path #For checking if files exist
import os #For making directories

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook
# %matplotlib inline

import re

# %%
import nltk
nlp = spacy.load('en_core_web_sm')

def word_tokenize(word_list):
    tokenized = []
    # pass word list through language model.
    doc = nlp(word_list)
    for token in doc:
        if not token.is_punct and len(token.text.strip()) > 0:
            tokenized.append(token.text)
    return tokenized

def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

# %%
def make_soup(url):
    '''
    A helper function to simply making a BeautifulSoup object from a function.
    Input: a full URL.
    Returns: a BeautifulSoup object.
    '''
    return bs4.BeautifulSoup(requests.get(url).text, 'html.parser')

def extract_first(lst): 
    '''
    A helper function to get the first element of each sublist within a list.
    Credit: https://www.geeksforgeeks.org/python-get-first-element-of-each-sublist/
    Returns: a list.
    '''
    return list(list(zip(*lst))[0])
        
"""
    class pageNode:
    '''
    A class object to represent a scraped webpage. Recursively generates children up to the specified
    capacity. Contains list of children pageNode objects within it.
    Inputs:
        dist_to_parent: how many "layers" of children separate this pageNode from the origin.
        max_dist: how many levels of recursion/children generation are permissable.
        base_url: the base URL to use when interpreting relative hyperlinks on the page.
        page_url: the URL which defines this pageNode, i.e. the page being scraped.
        sourceParNum: paragraph number of the source of the URL in the original webpage.
        sourceText: the paragraph text of the source of the URL in the original webpage. 
    '''
    def __init__(self, dist_to_parent, max_dist, base_url, page_url, sourceParNum, sourceText):
        #self.soup = make_soup(page_url)
        #if make_soup(base_url) == None:
        #    print("THIS DATAFRAME IS EMPTY")
        #    base_url = 'https://this-page-intentionally-left-blank.org/'
        self.df = extract_marx_text(page_url, sourceParNum, sourceText)
        self.refs = extract_marx_refs(make_soup(page_url),base_url)
        self.dist_to_parent = dist_to_parent
        self.children = []
        if self.dist_to_parent < max_dist:
            for url_tuple in self.refs:
                self.children.append(pageNode(self.dist_to_parent+1,max_dist,base_url,url_tuple[0],
                                              url_tuple[1],url_tuple[2]))
            for child in self.children:
                self.df = self.df.append(child.df)
"""                
                
def scrape_index(link='https://www.marxists.org/archive/marx/works/date/index.htm',
                 base_url='https://www.marxists.org/archive/marx/works/date/index.htm'):
    soup_obj = make_soup(link)
    contentPTags = soup_obj.body.findAll('p')
    
    index_tuples = []
    #parsDict = {'link' : [], 'paragraph-number' : [], 'paragraph_text' : []}
    for paragraphNum, pTag in enumerate(contentPTags):
        tagLinks = pTag.findAll('a',href=re.compile('htm$'),class_=False) #href=re.compile('htm$')
        #print(tagLinks)
        #print("next p tag")
        for aTag in tagLinks:
            relurl = aTag.get('href')
            linkText = aTag.text
            index_tuples.append((
                urllib.parse.urljoin(base_url, relurl),
                linkText
                ))
            #parsDict['link'].append(urllib.parse.urljoin(base_url, relurl))
            #parsDict['paragraph-number'].append(paragraphNum)
            #parsDict['paragraph_text'].append(linkText)
            
    return index_tuples    #pandas.DataFrame(parsDict)

def scrape_mecw(link='http://hiaw.org/defcon6/works/cw/index.html',
                 base_url='http://hiaw.org/defcon6/works/cw/index.html'):
    soup_obj = make_soup(link)
    contentPTags = soup_obj.body.findAll('p')
    
    index_tuples = []
    #parsDict = {'link' : [], 'paragraph-number' : [], 'paragraph_text' : []}
    for paragraphNum, pTag in enumerate(contentPTags):
        tagLinks = pTag.findAll('a') #,,class_=False,href=re.compile(r'index/.html')
        #print(tagLinks)
        #print("next p tag")
        for aTag in tagLinks:
            relurl = aTag.get('href')
            linkText = aTag.text
            index_tuples.append((
                urllib.parse.urljoin(base_url, relurl),
                linkText
                ))
            #parsDict['link'].append(urllib.parse.urljoin(base_url, relurl))
            #parsDict['paragraph-number'].append(paragraphNum)
            #parsDict['paragraph_text'].append(linkText)
            
    return index_tuples    #pandas.DataFrame(parsDict)

def check_atag(atag):
    relurl = atag.get('href')
    link_text = atag.text
    #print(link_text)
    if "Collected Works" in link_text:
        return False
    elif "HISTORY  ISA  WEAPON" in link_text:
        return False
    elif link_text=="":
        return False
    elif "History Is A Weapon" in link_text:
        return False
    elif "for small screens" in link_text:
        return False
    elif re.search(r"Notes$", link_text):
        return False
    else:
        if relurl==re.compile(r"index.html$"):
            return False
        else:
            return True

def scrape_index(link,source_text):
    base_url=link
    soup_obj = make_soup(link)
    #contentPTags = soup_obj.body.findAll('p')
    
    index_tuples = []
    #forbidden_words = ["Collected Works"]
    #parsDict = {'link' : [], 'paragraph-number' : [], 'paragraph_text' : []}
    #for paragraphNum, pTag in enumerate(contentPTags):
        #tagLinks = pTag.findAll('a') #,,class_=False,href=re.compile(r'index/.html')
        #print(tagLinks)
        #print("next p tag")
    for aTag in soup_obj.body.findAll('a'):
        if check_atag(aTag):
            relurl = aTag.get('href')
            linkText = aTag.text
            index_tuples.append((
                link,
                source_text,
                urllib.parse.urljoin(base_url, relurl),
                linkText
                ))
            #parsDict['link'].append(urllib.parse.urljoin(base_url, relurl))
            #parsDict['paragraph-number'].append(paragraphNum)
            #parsDict['paragraph_text'].append(linkText)
            
    return index_tuples    #pandas.DataFrame(parsDict)

def extract_marx_text(link_bigtuple):
    master_link=link_bigtuple[0]
    master_sourcetext=link_bigtuple[1]
    link=link_bigtuple[2]
    link_text=link_bigtuple[3]
    
    marxContentSoup = make_soup(link)
    parsDict = {'vol_source' : [], 'vol_name': [], 'link_source' : [],  
                'link_name' : [], 'paragraph_text': []}
    
    if marxContentSoup.body is None:
        return pandas.DataFrame(parsDict)
    else:
        contentPTags = marxContentSoup.body.findAll('p')
    
        for parNum, pTag in enumerate(contentPTags):
            if pTag=="":
                continue
            else: 
                #print("Appending real text")
                modA = re.sub(r'[\r\n]',' ',pTag.text) #remove random line breaks
                #modB = re.sub(r'\|p.{1,5}\|','',modA) #remove page number references
                #modC = re.sub(r'\[.+\]','',modB) #remove translator's notes
                #modD = re.sub(r'Karl Marx.','',modC) #remove website header
                #modE = re.sub(r'Next Section |  Table of Contents Marx-Engels Archive','',modD) #removed website footer
                #modF = re.sub(r'\xa0',' ',modE)
        
                parsDict['vol_source'].append(master_link)
                parsDict['vol_name'].append(master_sourcetext)
                parsDict['link_source'].append(link)
                parsDict['link_name'].append(link_text)
                parsDict['paragraph_text'].append(modA)
        
        #print(pandas.DataFrame(parsDict).head(5))
        #print("Testing")
        return pandas.DataFrame(parsDict)

def compile_mecw(i,j):
    mecw_index = scrape_mecw()
    #i = vol + 1
    
    volume_links = []
    for link_tuple in mecw_index[i:j]:
        if not link_tuple[1]=="":
            volume_links.append(scrape_index(link_tuple[0],link_tuple[1]))
    
    parsDict = {'vol_source' : [], 'vol_name': [], 'link_source' : [],  
                'link_name' : [], 'paragraph_text': []}
    master_table = pandas.DataFrame(parsDict)
    
    progress = 0
    dataframe_list = []
    for volume_list in volume_links:
        if len(volume_list) > 0:
            for content_tuple in volume_list: 
                #print(content_tuple)
                dataframe_list.append(extract_marx_text(content_tuple))
            progress += 1
            print("DEBUG: Progress =",progress)
    
    return pandas.concat(dataframe_list)

# %%
data = compile_mecw(2,51)
data
# Out:
# DEBUG: Progress = 1
# DEBUG: Progress = 2
# DEBUG: Progress = 3
# DEBUG: Progress = 4
# DEBUG: Progress = 5
# DEBUG: Progress = 6
# DEBUG: Progress = 7
# DEBUG: Progress = 8
# DEBUG: Progress = 9
# DEBUG: Progress = 10
# DEBUG: Progress = 11
# DEBUG: Progress = 12
# DEBUG: Progress = 13
# DEBUG: Progress = 14
# DEBUG: Progress = 15
# DEBUG: Progress = 16
# DEBUG: Progress = 17
# DEBUG: Progress = 18
# DEBUG: Progress = 19
# DEBUG: Progress = 20
# DEBUG: Progress = 21
# DEBUG: Progress = 22
# DEBUG: Progress = 23
# DEBUG: Progress = 24
# DEBUG: Progress = 25
# DEBUG: Progress = 26
# DEBUG: Progress = 27
# DEBUG: Progress = 28
# DEBUG: Progress = 29
# DEBUG: Progress = 30
# DEBUG: Progress = 31
# DEBUG: Progress = 32
# DEBUG: Progress = 33
# DEBUG: Progress = 34
# DEBUG: Progress = 35
# DEBUG: Progress = 36
# DEBUG: Progress = 37
# DEBUG: Progress = 38
# DEBUG: Progress = 39
# DEBUG: Progress = 40
# DEBUG: Progress = 41
# DEBUG: Progress = 42
# DEBUG: Progress = 43
# DEBUG: Progress = 44
# DEBUG: Progress = 45
# DEBUG: Progress = 46
# DEBUG: Progress = 47
# DEBUG: Progress = 48
# DEBUG: Progress = 49
#                                            vol_source   vol_name  \
# 0   http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# 1   http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# 2   http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# 3   http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# 4   http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# ..                                                ...        ...
# 12  http://hiaw.org/defcon6/works/cw/volume49/inde...  Volume 49
# 13  http://hiaw.org/defcon6/works/cw/volume49/inde...  Volume 49
# 14  http://hiaw.org/defcon6/works/cw/volume49/inde...  Volume 49
# 15  http://hiaw.org/defcon6/works/cw/volume49/inde...  Volume 49
# 16  http://hiaw.org/defcon6/works/cw/volume49/inde...  Volume 49
#
#                                           link_source  \
# 0   http://hiaw.org/defcon6/works/cw/volume01/intr...
# 1   http://hiaw.org/defcon6/works/cw/volume01/intr...
# 2   http://hiaw.org/defcon6/works/cw/volume01/intr...
# 3   http://hiaw.org/defcon6/works/cw/volume01/intr...
# 4   http://hiaw.org/defcon6/works/cw/volume01/intr...
# ..                                                ...
# 12  http://hiaw.org/defcon6/works/1892/letters/92_...
# 13  http://hiaw.org/defcon6/works/1892/letters/92_...
# 14  http://hiaw.org/defcon6/works/1892/letters/92_...
# 15  http://hiaw.org/defcon6/works/1892/letters/92_...
# 16  http://hiaw.org/defcon6/works/1892/letters/92_...
#
#                                 link_name  \
# 0                    General Introduction
# 1                    General Introduction
# 2                    General Introduction
# 3                    General Introduction
# 4                    General Introduction
# ..                                    ...
# 12  Engels to Franz Mehring. 28 September
# 13  Engels to Franz Mehring. 28 September
# 14  Engels to Franz Mehring. 28 September
# 15  Engels to Franz Mehring. 28 September
# 16  Engels to Franz Mehring. 28 September
#
#                                        paragraph_text
# 0                         Marx Engels Collected Works
# 1   KARL MARX and FREDERICK ENGELS were the author...
# 2   Theirs was a unique collaboration in theoretic...
# 3   Both Marx and Engels began their adult lives a...
# 4   They were revolutionary thinkers who assailed ...
# ..                                                ...
# 12  2. Adam Heinrich M�ller (1779-1829)  –  German...
# 13  3. Joseph Marie de Maistre (1753-1821)  –  Fre...
# 14  4. Engels refers to Lavergne-Peguilhen, Grundz...
# 15
# 16                                   Letters Archive
#
# [179955 rows x 5 columns]

# %%
pandas.options.display.max_rows = 5000
data[:4999]
# Out:
#                                             vol_source  vol_name  \
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 34   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 35   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 36   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 37   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 38   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 39   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 40   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 41   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 42   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 43   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 44   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 45   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 46   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 47   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 48   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 49   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 50   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 51   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 52   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 53   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 54   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 55   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 34   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 35   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 36   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 37   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 38   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 39   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 40   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 34   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 35   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 36   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 37   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 38   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 39   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 40   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 41   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 42   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 43   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 44   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 45   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 46   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 47   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 48   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 49   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 50   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 51   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 52   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 53   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 54   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 55   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 56   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 34   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 35   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 36   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 37   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 38   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 39   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 40   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 41   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 42   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 43   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 44   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 45   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 46   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 47   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 48   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 49   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 50   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 51   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 52   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 53   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 54   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 55   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 56   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 57   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 58   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 59   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 60   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 61   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 62   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 63   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 64   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 65   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 66   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 67   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 68   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 69   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 70   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 71   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 72   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 73   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 74   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 75   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 76   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 77   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 78   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 79   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 80   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 81   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 82   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 83   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 84   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 85   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 86   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 87   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 88   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 89   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 90   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 91   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 92   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 93   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 94   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 95   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 96   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 97   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 98   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 99   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 100  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 101  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 102  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 103  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 104  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 105  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 106  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 107  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 108  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 109  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 110  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 111  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 112  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 113  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 114  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 115  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 116  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 117  http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 34   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 35   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 36   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 37   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 38   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 39   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 40   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 41   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 42   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 43   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 44   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 45   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 46   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 47   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 48   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 49   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 50   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 51   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 52   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 53   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 54   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 55   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 56   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 57   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 58   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 59   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 60   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 61   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 62   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 63   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 64   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 65   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 66   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 67   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 68   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 69   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 70   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 71   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 72   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 73   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 74   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 75   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 76   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 77   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 78   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 79   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 80   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 81   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 82   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 83   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 34   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 35   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 36   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 37   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 38   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 39   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 40   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 41   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 42   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 43   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 44   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 45   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 46   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 47   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 48   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 49   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 50   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 51   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 52   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 53   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 54   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 55   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 56   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 57   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 58   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 59   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 60   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 61   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 62   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 63   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 64   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 65   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 66   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 67   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 68   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 69   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 7    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 8    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 9    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 10   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 11   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 12   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 13   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 14   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 15   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 16   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 17   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 18   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 19   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 20   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 21   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 22   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 23   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 24   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 25   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 26   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 27   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 28   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 29   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 30   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 31   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 32   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 33   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 34   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 35   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 36   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 37   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 38   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 39   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 40   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 41   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 42   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 43   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 44   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 45   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 46   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 47   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 48   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 49   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 50   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 51   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 52   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 53   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 54   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 55   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 56   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 57   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 58   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 59   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 60   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 61   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 62   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 63   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 64   http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 0    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 1    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 2    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 3    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 4    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 5    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# 6    http://hiaw.org/defcon6/works/cw/volume01/inde...  Volume 1
# ...
# 54    1839 Works |  Telegraph-Deutschland |  Marx/E...
# 0                      Works of Frederick Engels, 1839
# 1    Written:about April 27, 1839 First published:i...
# 2                                 Dear Bremen Courier,
# 3    Please don’t be offended   If you've become th...
# 4    My poems cost little effort when I did them;  ...
# 5                                   Theodor Hildebrand
# 6
# 7                                 Marx/Engels Archive
# 0                      Works of Frederick Engels, 1839
# 1    Written: on May 6, 1839  First published: in t...
# 2                      To Herr Dr. Runkel in Elberfeld
# 3                                   Elberfeld, May 6th
# 4    You have violently attacked me and my “Letters...
# 5    Herr Runkel, I do not, as you accuse me of doi...
# 6             The author of the Letters from Wuppertal
# 7
# 8                                 Marx/Engels Archive
# 0                      Works of Frederick Engels, 1839
# 1    Written: in May 1839 First published: in the T...
# 2    In a recent sermon in Elberfeld on Joshua 10:1...
# 3
# 4                                 Marx/Engels Archive
# 0                      Works of Frederick Engels, 1839
# 1    Written: in the autumn of 1839 First published...
# 2    For some time there have been loud and bitter ...
# 3    Pilgrim: Though lamb of Jesus’ flock you be,  ...
# 4    Little Lamb: Oppressed, but only to arise,  Th...
# 5    this is no imitation, but Krummacher himself! ...
# 6    Dear reader, forgive me for presenting you wit...
# 7
# 8                                 Marx/Engels Archive
# 0                      Works of Frederick Engels, 1839
# 1    Written: in May-October 1839 First published: ...
# 2    [German Volksb�cher were similar to the Englis...
# 3    Is it not a great commendation for a book to b...
# 4    If, generally speaking, the qualities which ca...
# 5    By these principles we should, and must, also ...
# 6    So long as opinions about the poetry of the Mi...
# 7    What in immortal song shall live forever,   Is...
# 8    many a poet may find yet one more reason to sa...
# 9    There is a very significant difference between...
# 10   If we view all these books in their entirety a...
# 11   To proceed now to individual cases, the most i...
# 12   Herzog Heinrich der L�we. — Unfortunately I ha...
# 13   “Thus the goal of the journey was reached, the...
# 14   Restore the legend in its old language, add ot...
# 15   Herzog Ernst. — The author of this book was no...
# 16   I now come to two legends which the German peo...
# 17   We have before us yet another series of popula...
# 18   In sharp contrast to these are the stories of ...
# 19   The first half of the book Kaiser Octavianus b...
# 20   In contrast to the tearful tales of suffering ...
# 21   Die Haimonskinder and Fortunat, where we again...
# 22   Last but not least, the Hundertj�hrige Kalende...
# 23   Nothing need be said of the rest of the popula...
# 24   But surely the German people and the best of t...
# 25   These old popular books with their old-fashion...
# 26
# 27                                Marx/Engels Archive
# 0                      Works of Frederick Engels, 1839
# 1    Written: in November-early December 1839 First...
# 2    I am a Sultan, driven by storms that blow,  My...
# 3    With these bombastic words Herr Beck approache...
# 4    There was much boldness in his first collectio...
# 5    The Young Literature developed so rapidly and ...
# 6    Beck’s N�chte appeared shortly before Freiligr...
# 7    The N�chte are chaos. Everything lies in motle...
# 8    Oh, how the frenzied, flashing images  Race th...
# 9                      fit not B�rne but Beck himself.
# 10   The image which Beck gives of B�rne in his fir...
# 11   Before a definite judgment of the N�chte could...
# 12   With Der fahrende Poet Beck had formally enter...
# 13   A year passed. Except for a few poems nothing ...
# 14   A friend told me during a concert that Beck’s ...
# 15   Only the enormous dreaming in these songs stil...
# 16   Teardrop, not in vain  So large and round a-br...
# 17   How stupid it is! The better part of the whole...
# 18   To conclude there are attempts at the ballad. ...
# 19   After several theatre managements had declared...
# 20
# 21                                Marx/Engels Archive
# 0                      Works of Frederick Engels, 1840
# 1    Written: in November 1839 — January 1840 First...
# 2    There is nothing new under the sun! That is on...
# 3    Or let us tackle the subject in another way! A...
# 4    “The form taken by history,” states an intelli...
# 5    Yet I prefer a free hand-drawn spiral, the tur...
# 6    It is at just such a point in history that we ...
# 7    We do not need to go far afield to encounter t...
# 8    Such a room is of course eminently suitable fo...
# 9    While in all this the reproduction of the past...
# 10   The analogy is undeniable; will the conclusion...
# 11   But we must go farther back than to the Encycl...
# 12   Withered the palm, blown off the desert sand. ...
# 13   And, certainly, if Freiligrath were not to do ...
# 14   I confess to being perplexed how to arrange th...
# 15
# 16                                Marx/Engels Archive
# 0                      Works of Frederick Engels, 1840
# 1    Written: in December 1839 First published: in ...
# 2    Among the poetic offspring of the Restoration ...
# 3    Platen’s imagination followed timorously the b...
# 4    That his views, too, make him more akin to B�r...
# 5
# 6                                 Marx/Engels Archive
# 0                      Works of Frederick Engels, 1840
# 1    Translated: in the first half of 1840 First pu...
# 2    Shall then the Poet’s voice sing, only telling...
# 3    They were not prodigal in olden days,  But fre...
# 4    But Nature in the end bestirs herself,  To giv...
# 5    He spoke. And there was Print. And lo! all Eur...
# 6    It stands, although the structure of its power...
# 7    That, then, was the first wreath of bay to dec...
# 8    What does it help you, then, to conquer Heaven...
# 9     And so it did, only to pour  Its bitterness i...
# 10    And the Despots heard,  And wielded in their ...
# 11   “O senseless ones! Those very high-piled faggo...
# 12   And then the great day came  On which a mortal...
# 13   Oh, free, yes, free! Sweetest of words, the br...
# 14   Now both of them are gone from Earth for ever,...
# 15   Do you not see that column soaring there,  Tow...
# 16                                              Bremen
# 17
# 18                                Marx/Engels Archive
# 0                      Works of Frederick Engels, 1840
# 1    Written: in January-March 1840 First published...
# 2    G�rres’ troupe of tight-rope dancers has acqui...
# 3    “What should I give you for your refreshment?”...
# 4    One is perplexed how to deal with this nonsens...
# 5    Franz Karl Joel Jacoby’s confusion of language...
# 6    The actual content of this masterpiece, which ...
# 7    In Joel Jacoby we see the horrifying extreme t...
# 8
# 9                                 Marx/Engels Archive
# 0                      Works of Frederick Engels, 1840
# 1    Written: in January-April 1840 First published...
# 2    Dies irae, dies illa  Saecla solvet in favilla...
# 3    The day that Luther produced the original text...
# 4    “which belongs wholly to the public, a time of...
# 5    I quote these words here merely to show how li...
# 6    And yet we have lost much by its death. What j...
# 7    How morally — modestly — condescendingly the g...
# 8    But here the noble hero falls off his horse, a...
# 9    The foreword teaches us that world history doe...
# 10   It is clear that on account of his thorough st...
# 11                       they are truly in need of it.
# 12   The defunct Adelszeitung has indeed had some s...
# 13   And let them sleep in peace  Until the judgmen...
# 14   We, however, shall sing a requiem for it and p...
# 15   Tuba mirum spargens sonum  Per sepulcra region...
# 16   Do you not hear the trumpet, whose sound overt...
# 17
# 18                                Marx/Engels Archive
# 0                      Works of Frederick Engels, 1840
# 1    Written: in March 1840 First published: in the...
# 2    One would have thought that after Gutzkow’s we...
# 3    Nevertheless there are those among our critics...
# 4    But before discussing this play we must consid...
# 5    Hamlet in Wittenberg already gives us the outl...
# 6    Now we come to our main work, K�nig Saul. Gutz...
# 7    Another reason why superficiality could dismis...
# 8    Grouped in the centre of the drama. are three ...
# 9    Samuel stands at the transition to culture; he...
# 10   The third element, which emerges victorious fr...
# 11   In order not to interrupt the development of t...
# 12   Of the play’s remaining characters the best dr...
# 13   I trust I shall be excused for not giving a co...
# 14   In the second act, the scene with the Philisti...
# 15   Here also that pitfall of the dramatist, the t...
# 16   The language of the play, as was to be expecte...
# 17   I need but make you up as verses For fun into ...
# 18   what does it mean? — The basic thought of such...
# 19   Unsuccessful images have not been entirely avo...
# 20   The anger of the priest From whom the people f...
# 21   Here the crown is already an allegory for king...
# 22   Circumstances have prevented me from gaining a...
# 23   Werner, [66] Gutzkow’s most recent work, has r...
# 24   However, we hope that Gutzkow, having prepared...
# 25   The Young Literature has a weapon through whic...
# 26   In these circumstances we can say of our autho...
# 27   Forgive me, dear reader, you have probably lon...
# 28   Whether. Gutzkow picked up the first stone, wh...
# 29   Gutzkow’s literary work and aspirations bear t...
# 30   While the latter’s nature thus proves to be th...
# 31   Besides these differences, the intellectual. d...
# 32   So Gutzkow and Mundt confronted each other whe...
# 33   Mundt polemicised little and insignificantly, ...
# 34   Gutzkow, by contrast, took real pleasure in po...
# 35   Towards the end of 1838 a third fighter entere...
# 36   The chief foundation of K�hne’s literary statu...
# 37   In K�hne one must further distinguish two peri...
# 38   You can lay open, like the human brain,  The v...
# 39   The same lack of precise characterisation is d...
# 40   K�hne had long been challenged by Gutzkow but ...
# 41   This Jahrbuch der Literatur, however, bore wit...
# 42   To prevent the once more slackening polemic fr...
# 43   The dispute between Gutzkow and Beck might wel...
# 44   Gutzkow now adopted a hostile position to all ...
# 45   This is how matters stand at present; Mundt ha...
# 46
# 47                                Marx/Engels Archive
# 0                      Works of Frederick Engels, 1840
# 1    Written: in March 1840 First published: in the...
# 2    One would have thought that after Gutzkow’s we...
# 3    Nevertheless there are those among our critics...
# 4    But before discussing this play we must consid...
# 5    Hamlet in Wittenberg already gives us the outl...
# 6    Now we come to our main work, K�nig Saul. Gutz...
# 7    Another reason why superficiality could dismis...
# 8    Grouped in the centre of the drama. are three ...
# 9    Samuel stands at the transition to culture; he...
# 10   The third element, which emerges victorious fr...
# 11   In order not to interrupt the development of t...
# 12   Of the play’s remaining characters the best dr...
# 13   I trust I shall be excused for not giving a co...
# 14   In the second act, the scene with the Philisti...
# 15   Here also that pitfall of the dramatist, the t...
# 16   The language of the play, as was to be expecte...
# 17   I need but make you up as verses For fun into ...
# 18   what does it mean? — The basic thought of such...
# 19   Unsuccessful images have not been entirely avo...
# 20   The anger of the priest From whom the people f...
# 21   Here the crown is already an allegory for king...
# 22   Circumstances have prevented me from gaining a...
# 23   Werner, [66] Gutzkow’s most recent work, has r...
# 24   However, we hope that Gutzkow, having prepared...
# 25   The Young Literature has a weapon through whic...
# 26   In these circumstances we can say of our autho...
# 27   Forgive me, dear reader, you have probably lon...
# 28   Whether. Gutzkow picked up the first stone, wh...
# 29   Gutzkow’s literary work and aspirations bear t...
# 30   While the latter’s nature thus proves to be th...
# 31   Besides these differences, the intellectual. d...
# 32   So Gutzkow and Mundt confronted each other whe...
# 33   Mundt polemicised little and insignificantly, ...
# 34   Gutzkow, by contrast, took real pleasure in po...
# 35   Towards the end of 1838 a third fighter entere...
# 36   The chief foundation of K�hne’s literary statu...
# 37   In K�hne one must further distinguish two peri...
# 38   You can lay open, like the human brain,  The v...
# 39   The same lack of precise characterisation is d...
# 40   K�hne had long been challenged by Gutzkow but ...
# 41   This Jahrbuch der Literatur, however, bore wit...
# 42   To prevent the once more slackening polemic fr...
# 43   The dispute between Gutzkow and Beck might wel...
# 44   Gutzkow now adopted a hostile position to all ...
# 45   This is how matters stand at present; Mundt ha...
# 46
# 47                                Marx/Engels Archive
# 0                      Works of Frederick Engels, 1840
# 1    Written: in March 1840 First published: in the...
# 2    One would have thought that after Gutzkow’s we...
# 3    Nevertheless there are those among our critics...
# 4    But before discussing this play we must consid...
# 5    Hamlet in Wittenberg already gives us the outl...
# 6    Now we come to our main work, K�nig Saul. Gutz...
# 7    Another reason why superficiality could dismis...
# 8    Grouped in the centre of the drama. are three ...
# 9    Samuel stands at the transition to culture; he...
# 10   The third element, which emerges victorious fr...
# 11   In order not to interrupt the development of t...
# 12   Of the play’s remaining characters the best dr...
# 13   I trust I shall be excused for not giving a co...
# 14   In the second act, the scene with the Philisti...
# 15   Here also that pitfall of the dramatist, the t...
# 16   The language of the play, as was to be expecte...
# 17   I need but make you up as verses For fun into ...
# 18   what does it mean? — The basic thought of such...
# 19   Unsuccessful images have not been entirely avo...
# 20   The anger of the priest From whom the people f...
# 21   Here the crown is already an allegory for king...
# 22   Circumstances have prevented me from gaining a...
# 23   Werner, [66] Gutzkow’s most recent work, has r...
# 24   However, we hope that Gutzkow, having prepared...
# 25   The Young Literature has a weapon through whic...
# 26   In these circumstances we can say of our autho...
# 27   Forgive me, dear reader, you have probably lon...
# 28   Whether. Gutzkow picked up the first stone, wh...
# 29   Gutzkow’s literary work and aspirations bear t...

# %%
filtA = [len(text) > 39 for text in data.paragraph_text]
marx_onefilt = data[filtA].reset_index()
marx_onefilt.to_csv(r'C:\Users\super\comp_work\Homework-Notebooks\votava_project_data\mecw_frag.csv', index_label=False, sep=',')
