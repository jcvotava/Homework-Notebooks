# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
import lucem_illud #pip install git+git://github.com/UChicago-Computational-Content-Analysis/lucem_illud.git

#All these packages need to be installed from pip
import requests #for http requests
import bs4 #called `beautifulsoup4`, an html parser
import pandas #gives us DataFrames
import docx #reading MS doc files, install as `python-docx`

#Stuff for pdfs
#Install as `pdfminer2`
import pdfminer.pdfinterp
import pdfminer.converter
import pdfminer.layout
import pdfminer.pdfpage

#These come with Python
import re #for regexs
import urllib.parse #For joining urls
import io #for making http requests look like files
import json #For Tumblr API responses
import os.path #For checking if files exist
import os #For making directories

#All these packages need to be installed from pip
import requests #for http requests
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import wordcloud #Makes word clouds
import numpy as np #For divergences/distances
import scipy #For divergences/distances
import seaborn as sns #makes our plots look nicer
import sklearn.manifold #For a manifold plot
import json #For API responses
import urllib.parse #For joining urls

# comp-linguistics
import spacy

#Displays the graphs
import graphviz #You also need to install the command line graphviz

#These are from the standard library
import os.path
import zipfile
import subprocess
import io
import tempfile

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook
# %matplotlib inline

import numpy as np #For arrays
import scipy as sp #For some stats
import pandas #Gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import seaborn #Makes the graphics look nicer
import pyanno #On python3 make sure to pip install pyanno3

#We need to import these this way due to how pyanno is setup
from pyanno.measures import pairwise_matrix, agreement, cohens_kappa, cohens_weighted_kappa, fleiss_kappa, krippendorffs_alpha, pearsons_rho, scotts_pi, spearmans_rho
from pyanno.annotations import AnnotationsContainer
from pyanno.models import ModelA, ModelBt, ModelB

from functools import reduce
from itertools import permutations
import math


#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning
# %matplotlib inline

import os #For looking through files
import os.path #For managing file paths

import gensim


#All these packages need to be installed from pip
#These are all for the cluster detection
import sklearn
import sklearn.feature_extraction.text
import sklearn.pipeline
import sklearn.preprocessing
import sklearn.datasets
import sklearn.cluster
import sklearn.decomposition
import sklearn.metrics

import scipy #For hierarchical clustering and some visuals
#import scipy.cluster.hierarchy
#!pip install gensim
#!pip install cython
#import gensim #For topic modeling
import requests #For downloading our datasets
import numpy as np #for arrays
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import matplotlib.cm #Still for graphics
import seaborn as sns #Makes the graphics look nicer

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning, it
# %matplotlib inline

import itertools
import json

import torch 
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertConfig 
from transformers import AdamW, BertForSequenceClassification
from tqdm import tqdm, trange
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
import keras

# %% [markdown]
# Preparatory / scratch cells (scroll down for experiments)
# .
#
# .
#
# .
#
# .
#
# .
#
# .

# %%
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
from keras.preprocessing.sequence import pad_sequences

# %%
capital_df = pandas.read_csv(r'C:\Users\super\comp_work\Homework-Notebooks\votava_project_data\capital.csv')
mecw_df = pandas.read_csv(r'C:\Users\super\comp_work\Homework-Notebooks\votava_project_data\mecw_marx.csv')
mecw_sents_df = pandas.read_csv(r'C:\Users\super\comp_work\Homework-Notebooks\votava_project_data\mecw_marx_sents.csv')
three_marx_df = pandas.read_csv(r'C:\Users\super\comp_work\Homework-Notebooks\votava_project_data\three_marx_frag.csv')
three_marx_sents_df = capital = pandas.read_csv(r'C:\Users\super\comp_work\Homework-Notebooks\votava_project_data\three_marx_sents.csv')

# %%
mecw_df
# Out:
#        index                                         vol_source   vol_name  \
# 0          1  http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# 1          2  http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# 2          3  http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# 3          4  http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# 4          5  http://hiaw.org/defcon6/works/cw/volume01/inde...   Volume 1
# ...      ...                                                ...        ...
# 67466      3  http://hiaw.org/defcon6/works/cw/volume46/inde...  Volume 46
# 67467      4  http://hiaw.org/defcon6/works/cw/volume46/inde...  Volume 46
# 67468      5  http://hiaw.org/defcon6/works/cw/volume46/inde...  Volume 46
# 67469      6  http://hiaw.org/defcon6/works/cw/volume46/inde...  Volume 46
# 67470      7  http://hiaw.org/defcon6/works/cw/volume46/inde...  Volume 46
#
#                                              link_source  \
# ...

# %%
mecw_sents_grouped = mecw_sents_df.groupby(by='vol_name',axis=0,sort=False).sum()

# %%
mecw_sents_grouped.to_csv(r'C:\Users\super\comp_work\Homework-Notebooks\votava_project_data\mecw_marx.csv', index_label=True, sep=',')

# %%
mecw_sents_grouped
# Out:
#                                                     src_name  \
# vol_name
# Volume 1   General IntroductionGeneral IntroductionGenera...
# Volume 3   PrefacePrefacePrefacePrefacePrefacePrefacePref...
# Volume 4   PrefacePrefacePrefacePrefacePrefacePrefacePref...
# Volume 5   PrefacePrefacePrefacePrefacePrefacePrefacePref...
# Volume 6   PrefacePrefacePrefacePrefacePrefacePrefacePref...
# Volume 7   PrefacePrefacePrefacePrefacePrefacePrefacePref...
# Volume 8   PrefacePrefacePrefacePrefacePrefacePrefacePref...
# Volume 9   PrefacePrefacePrefacePrefacePrefacePrefacePref...
# Volume 10  The German Social Democrats and The TimesThe G...
# Volume 11  Revolution and Counter-Revolution in GermanyRe...
# Volume 12  Hirsch's ConfessionsHirsch's ConfessionsHirsch...
# Volume 13  Letter to the Labour ParliamentLetter to the L...
# Volume 14  News from IndiaNews from IndiaNews from IndiaN...
# Volume 15  Revelations of the Diplomatic History of the 1...
# ...

# %%
three_sents_grouped2 = mecw_sents_grouped[mecw_sents_grouped.index.isin(['Volume 3','Volume 24','Volume 35'],)]
three_sents_grouped2
# Out:
#                                                     src_name  \
# vol_name
# Volume 3   PrefacePrefacePrefacePrefacePrefacePrefacePref...
# Volume 24  A Polish ProclamationA Polish ProclamationA Po...
# Volume 35  CAPITAL, Volume ICAPITAL, Volume ICAPITAL, Vol...
#
#                                               tokenized_sent
# vol_name
# Volume 3   ['The', 'third', 'volume', 'of', 'the', 'works...
# Volume 24  ['Originally', 'published', 'in', 'Volksstaat'...
# Volume 35  ['First', 'published', 'in', 'German', 'in', '...

# %%
three_marx_condensed = three_marx_sents_df.drop(columns=['src_name','raw_sent'])

#three_sents_grouped = three_marx_sents_df.groupby(by='vol_name',axis=0,sort=False).sum()
# Out:
#          vol_name                                     tokenized_sent
# 40122    Volume 3  ['The', 'third', 'volume', 'of', 'the', 'works...
# 40123    Volume 3  ['The', 'contents', 'fall', 'into', 'two', 'pa...
# 40124    Volume 3  ['Included', 'as', 'appendices', 'are', 'biogr...
# 40125    Volume 3  ['This', 'period', 'marked', 'an', 'important'...
# 40126    Volume 3  ['The', 'development', 'of', 'each', 'proceede...
# ...           ...                                                ...
# 682403  Volume 35  ['The', 'first', 'and', 'main', 'object', 'at'...
# 682404  Volume 35  ['The', 'Land', 'Law', 'of', 'Victoria', 'by',...
# 682405  Volume 35  ['C.', 'G.', 'Duffy', 'Minister', 'of', 'Publi...
# 682406  Volume 35  ['COVID-19', 'We', '’re', 'committed', 'to', '...
# 682407  Volume 35  ['Find', 'updates', 'on', 'operations', 'resou...
#
# [111562 rows x 2 columns]

# %%
three_sents_grouped = three_marx_sents_df.groupby(by='vol_name',axis=0,sort=False).sum()

# %%
three_grouped_condensed = three_sents_grouped.drop(columns=['src_name','raw_sent'])

# %%
three_grouped_condensed
# Out:
#                                               tokenized_sent
# vol_name
# Volume 3   ['The', 'third', 'volume', 'of', 'the', 'works...
# Volume 24  ['Originally', 'published', 'in', 'Volksstaat'...
# Volume 35  ['First', 'published', 'in', 'German', 'in', '...

# %%
import re

three_marx_dict = {'vol_num':['Volume 1','Volume 24','Volume 35'],'text_bag':[]}

for mega_list in three_grouped_condensed.tokenized_sent:
    #three_marx_dict['vol_num'].append(mega_list.index.to_list())
    cleaned_listA = re.sub(r"\[", '', mega_list)
    cleaned_listB = re.sub(r"\]", ' ', cleaned_listA)
    cleaned_listC = re.sub(r"'", '', cleaned_listB)
    textbag = cleaned_listC.split(", ")
    three_marx_dict['text_bag'].append(textbag)

# %%
three_textbag = pd.DataFrame(three_marx_dict)
three_textbag
# Out:
#      vol_num                                           text_bag
# 0   Volume 1  [The, third, volume, of, the, works, of, Marx,...
# 1  Volume 24  [Originally, published, in, Volksstaat, 11, Ju...
# 2  Volume 35  [First, published, in, German, in, 1867 First,...

# %%
vol_3_sents = three_marx_condensed[three_marx_condensed['vol_name']=='Volume 3'].tokenized_sent
vol_24_sents = three_marx_condensed[three_marx_condensed['vol_name']=='Volume 24'].tokenized_sent
vol_35_sents = three_marx_condensed[three_marx_condensed['vol_name']=='Volume 35'].tokenized_sent

# %%
vol_3_sents
# Out:
# 40122    ['The', 'third', 'volume', 'of', 'the', 'works...
# 40123    ['The', 'contents', 'fall', 'into', 'two', 'pa...
# 40124    ['Included', 'as', 'appendices', 'are', 'biogr...
# 40125    ['This', 'period', 'marked', 'an', 'important'...
# 40126    ['The', 'development', 'of', 'each', 'proceede...
#                                ...
# 51114       ['Dear', 'good', 'heart', 'of', 'my', 'heart']
# 51115    ['Do', 'write', 'to', 'me', 'again', 'quite', ...
# 51116    ['I', 'am', 'so', 'very', 'happy', 'when', 'I'...
# 51118                  ['sweet', 'little', 'wild', 'boar']
# 51119    ['You', 'dear', 'father', 'of', 'my', 'little'...
# Name: tokenized_sent, Length: 9598, dtype: object

# %%
def normalizeTokens(word_list, extra_stop=[]):
    #We can use a generator here as we just need to iterate over it
    normalized = []
    if type(word_list) == list and len(word_list) == 1:
        word_list = word_list[0]

    if type(word_list) == list:
        word_list = ' '.join([str(elem) for elem in word_list]) 

    doc = nlp(word_list.lower())
    
    # add the property of stop word to words considered as stop words
    if len(extra_stop) > 0:
        for stopword in extra_stop:
            lexeme = nlp.vocab[stopword]
            lexeme.is_stop = True

    for w in doc:
        # if it's not a stop word or punctuation mark, add it to our article
        if w.text != '\n' and not w.is_stop and not w.is_punct and not w.like_num and len(w.text.strip()) > 0:
            # we add the lematized version of the word
            normalized.append(str(w.lemma_))

    return normalized

# %%
import ast

vol_3_bag = []
for sent in vol_3_sents:
    vol_3_bag.extend(ast.literal_eval(sent))
    
vol_24_bag = []
for sent in vol_24_sents:
    vol_24_bag.extend(ast.literal_eval(sent))
    
vol_35_bag = []
for sent in vol_35_sents:
    vol_35_bag.extend(ast.literal_eval(sent))

# %%
nlp.max_length = 12000000
vol_3_norm = normalizeTokens(vol_3_bag)
vol_24_norm = normalizeTokens(vol_24_bag)
vol_35_norm = normalizeTokens(vol_35_bag)

# %%
vol_3_norm
# Out:
# ['volume',
#  'work',
#  'marx',
#  'engels',
#  'cover',
#  'period',
#  'march',
#  'august',
#  'close',
#  'collaboration',
#  'begin',
#  'content',
#  'fall',
#  'part',
#  'consist',
#  'marx',
#  'work',
#  'letter',
#  'preparatory',
#  'material',
#  'march',
#  'august',
#  'contain',
#  'engel',
#  'writing',
#  'june',
#  'include',
#  'appendix',
#  'biographical',
#  'document',
#  'marx',
#  'letter',
#  'wife',
#  'jenny',
#  'write',
#  'june',
#  'august',
#  'period',
#  'mark',
#  'important',
#  'stage',
#  'formation',
#  'world',
#  'outlook',
#  'marx',
#  'engel',
#  'accomplish',
#  'transition',
#  'idealism',
#  'materialism',
#  'standpoint',
#  'revolutionary',
#  'democracy',
#  'communism',
#  'development',
#  'proceed',
#  'main',
#  'independently',
#  'show',
#  'grow',
#  'interest',
#  'writing',
#  'activity',
#  'late',
#  'early',
#  'marx',
#  'engel',
#  'alike',
#  'opponent',
#  'exist',
#  'political',
#  'system',
#  'feudal',
# ...

# %% [markdown]
# Experiments Below
#
# .
#
# .
#
# .
#
# .
#
# .

# %% [markdown]
# Experiment A: Naive Word Counts

# %%
wordlist_dict = {'vol_names': [], 'word_list': []}
len(wordlist_dict['vol_names'])

# %%
# for vol_name in three_marx_sents_df.vol_name.unique():
#     wordlist_dict['vol_names'].append(vol_name)
#     print(vol_name,"IS NOW RUNNING")
#     vol_list = []
#     vol_list.append(mecw_sents_df.tokenized_sent[mecw_sents_df.vol_name == vol_name])
#     wordlist_dict['word_list'].append(vol_list)

# wordlist_df = pd.DataFrame(wordlist_dict)
# capital_tokens = []
# for text_list in capital_corpus.tokenized_text:
#     capital_tokens.extend(text_list)

# countedWords = wordCounter(capital_tokens)
# countedWords.sort_values('count', ascending=False, inplace=True)
# countedWords[:100]

# %%
import nltk
nlp = spacy.load('en_core_web_sm')

def word_tokenize(word_list):
    tokenized = []
    # pass word list through language model.
    doc = nlp(word_list)
    for token in doc:
        if not token.is_punct and len(token.text.strip()) > 0:
            tokenized.append(token.text)
    return tokenized

def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

# %%
vol_3_text = nltk.Text(vol_3_bag)
vol_24_text = nltk.Text(vol_24_bag)
vol_35_text = nltk.Text(vol_35_bag)

# %%
vol_3_text
# Out:
# <Text: The third volume of the works of Marx...>

# %%
print("Alienation, Vol 3:",vol_3_norm.count('alienation'))
print("Alienation, Vol 35:",vol_35_norm.count('alienation'))
print("Alienation, Vol 24:",vol_24_norm.count('alienation'))
# Out:
# Alienation, Vol 3: 143
# Alienation, Vol 35: 47
# Alienation, Vol 24: 0

# %%
print("Fetish, Vol 3:",vol_3_norm.count('fetish'))
print("Fetish, Vol 35:",vol_35_norm.count('fetish'))
print("Fetish, Vol 24:",vol_24_norm.count('fetish'))
# Out:
# Fetish, Vol 3: 3
# Fetish, Vol 35: 9
# Fetish, Vol 24: 0

# %%
vol_3_nbag = nltk.collocations.BigramCollocationFinder.from_words(vol_3_norm)
vol_24_nbag = nltk.collocations.BigramCollocationFinder.from_words(vol_24_norm)
vol_35_nbag = nltk.collocations.BigramCollocationFinder.from_words(vol_35_norm)

# %%
def bigramScoring(count, wordsTuple, total):
    return count

print(vol_3_nbag.nbest(bigramScoring, 10))
# Out:
# [('private', 'property'), ('civil', 'society'), ('political', 'economy'), ('land', 'property'), ('self', 'consciousness'), ('division', 'labour'), ('man', 'man'), ('right', 'man'), ('capital', 'labour'), ('landed', 'property')]

# %%
print("Forces of production, Vol 3:",vol_3_nbag.ngram_fd[('force', 'production')])
print("Forces of production, Vol 34:",vol_35_nbag.ngram_fd[('force', 'production')])
print("Forces of production, Vol 24:",vol_24_nbag.ngram_fd[('force', 'production')])
# Out:
# Forces of production, Vol 3: 1
# Forces of production, Vol 24: 1
# Forces of production, Vol 35: 5

# %%
print("Relations of production, Vol 3:",vol_3_nbag.ngram_fd[('relation', 'production')])
print("Relations of production, Vol 35:",vol_35_nbag.ngram_fd[('relation', 'production')])
print("Relations of production, Vol 24:",vol_24_nbag.ngram_fd[('relation', 'production')])
# Out:
# Relations of production, Vol 3: 4
# Relations of production, Vol 35: 23
# Relations of production, Vol 24: 0

# %% [markdown]
# Experiment B: Word Embeddings

# %%
print("Volume 3 / Young Marx:")
vol_3_text.common_contexts(['labour'])
print()
print("Volume 35 / Capital Marx:")
vol_35_text.common_contexts(['labour'])
print()
print("Volume 24 / Mature Marx:")
vol_24_text.common_contexts(['labour'])
# Out:
# Volume 3 / Young Marx:
# of_and of_is the_of of_in of_power of_to and_are of_against of_which
# of_so from_and of_the of_are of_increases and_is and_of and_and
# human_the into_and that_is
#
# Volume 35 / Capital Marx:
# the_of of_power of_and of_in of_is the_power his_power of_required
# but_l.c of_there immature_power free_if ’s_ceases night_on
# productive_and daily_in ’s_only the_process whose_is of_it
#
# Volume 24 / Mature Marx:
# etc_standard 1848_standard the_movement the_emancipation
# principles_standard districts_standard party_standard exhausting_the
# this_power of_embodied the_power his_power the_of german_movement
# whole_movement his_but their_power agricultural_beyond the_standard
# of_in

# %%
print("Volume 3 / Young Marx:")
vol_3_text.common_contexts(['time'])
print()
print("Volume 35 / Capital Marx:")
vol_35_text.common_contexts(['time'])
print()
print("Volume 24 / Mature Marx:")
vol_24_text.common_contexts(['time'])
# Out:
# Volume 3 / Young Marx:
# same_the the_being that_we the_when same_he same_publicise same_as
# from_to same_they the_of its_comes second_the its_and
# considerable_england the_to first_in short_without same_to the_you
# wealth_and
#
# Volume 35 / Capital Marx:
# the_of no_for of_of own_and a_when same_a own_the him_for
# limited_without worker_for his_becomes work_is a_but same_parliament
# over_to from_to to_prepared the_for the_i in_together
#
# Volume 24 / Mature Marx:
# same_foreign same_or longer_and labor_of the_of in_the the_being
# given_first a_when same_the the_and certain_gratis first_the that_in
# same_he the_when that_there present_he first_in that_the

# %% [markdown]
# Experiment C: Word Distribution

# %%
sns.reset_orig() #Seaborn messes with this plot, disabling it
print ("Vol 3 / Young Marx Lexical Dispersion")
vol_3_text.dispersion_plot(['alienation','capital','mode','production'])
print ("Vol 35 / Capital Marx Lexical Dispersion")
vol_35_text.dispersion_plot(['alienation','capital','mode','production'])
print ("Vol 24 / Mature Marx Lexical Dispersion")
vol_24_text.dispersion_plot(['alienation','capital','mode','production'])
sns.set() #Re-enabling seaborn
# Out:
# Vol 3 / Young Marx Lexical Dispersion
# Vol 35 / Capital Marx Lexical Dispersion
# Vol 24 / Mature Marx Lexical Dispersion

# %% [markdown]
# Experiment D: Distributional distance of corpora

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

def kl_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = scipy.stats.entropy(p, q)
    return D_kl

def chi2_divergence(X,Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    return scipy.stats.chisquare(p, q).statistic

def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)

# %%
vol_3_norm
# Out:
# ['volume',
#  'work',
#  'marx',
#  'engels',
#  'cover',
#  'period',
#  'march',
#  'august',
#  'close',
#  'collaboration',
#  'begin',
#  'content',
#  'fall',
#  'part',
#  'consist',
#  'marx',
#  'work',
#  'letter',
#  'preparatory',
#  'material',
#  'march',
#  'august',
#  'contain',
#  'engel',
#  'writing',
#  'june',
#  'include',
#  'appendix',
#  'biographical',
#  'document',
#  'marx',
#  'letter',
#  'wife',
#  'jenny',
#  'write',
#  'june',
#  'august',
#  'period',
#  'mark',
#  'important',
#  'stage',
#  'formation',
#  'world',
#  'outlook',
#  'marx',
#  'engel',
#  'accomplish',
#  'transition',
#  'idealism',
#  'materialism',
#  'standpoint',
#  'revolutionary',
#  'democracy',
#  'communism',
#  'development',
#  'proceed',
#  'main',
#  'independently',
#  'show',
#  'grow',
#  'interest',
#  'writing',
#  'activity',
#  'late',
#  'early',
#  'marx',
#  'engel',
#  'alike',
#  'opponent',
#  'exist',
#  'political',
#  'system',
#  'feudal',
# ...

# %%
corpora = [vol_3_norm,vol_35_norm,vol_24_norm]
fileids = ["Young / Vol3","Capital / Vol35","Mature / Vol24"]

print("KL distance")
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

print("KS distance")
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'KS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

print("ChiSq distance")
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'Chi2'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

print("Wasserstein distance")
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'Wasserstein'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()
# Out:
# KL distance
# KS distance
# ChiSq distance
# Wasserstein distance

# %% [markdown]
# Experiment E: KMeans Clustering

# %%
#initialize
threeTFVectorizer = sklearn.feature_extraction.text.TfidfVectorizer(max_df=0.4, max_features=2000, min_df=10, stop_words='english', norm='l2')
#train
threeTFVects = threeTFVectorizer.fit_transform(three_marx_sents_df['raw_sent'])

threePCA = sklearn.decomposition.PCA
threepca = threePCA(n_components = 2).fit(threeTFVects.toarray())
three_reduced_data = threepca.transform(threeTFVects.toarray())

def plotSilhouette(reduced_data,n_clusters, X):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize = (15,5))
    
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])
    clusterer = sklearn.cluster.KMeans(n_clusters=n_clusters, max_iter=3000, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    
    silhouette_avg = sklearn.metrics.silhouette_score(X, cluster_labels)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = sklearn.metrics.silhouette_samples(X, cluster_labels)

    y_lower = 10
    
    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        cmap = matplotlib.cm.get_cmap("nipy_spectral")
        color = cmap(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10
    
    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    cmap = matplotlib.cm.get_cmap("nipy_spectral")
    colors = cmap(float(i) / n_clusters)
    
    ax2.scatter(three_reduced_data[:, 0], three_reduced_data[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors) 

    # Labeling the clusters
    centers_c = clusterer.cluster_centers_
    projected_centers = cappca.transform(centers_c)
    # Draw white circles at cluster centers
    ax2.scatter(projected_centers[:, 0], projected_centers[:, 1],
                marker='o', c="white", alpha=1, s=200)

    for i, c in enumerate(projected_centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1, s=50)

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("PC 1")
    ax2.set_ylabel("PC 2")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')
    plt.show()
    print("For n_clusters = {}, The average silhouette_score is : {:.3f}".format(n_clusters, silhouette_avg))

# %%
X = threeTFVects.toarray()
plotSilhouette(three_reduced_data, 16, X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-208-0434527a13ee> in <module>
#       1 X = threeTFVects.toarray()
# ----> 2 plotSilhouette(three_reduced_data, 16, X)
#
# <ipython-input-201-3806a32b4561> in plotSilhouette(reduced_data, n_clusters, X)
#      53     colors = cmap(float(i) / n_clusters)
#      54
# ---> 55     ax2.scatter(cap_reduced_data[:, 0], cap_reduced_data[:, 1], marker='.', s=30, lw=0, alpha=0.7,
#      56                 c=colors)
#      57
#
# NameError: name 'cap_reduced_data' is not defined

# %%
def compare_sil(max_n, X):
    x = []
    y = []
    for i in range(2,max_n):
        clusterer = sklearn.cluster.KMeans(n_clusters=i, random_state=10)
        cluster_labels = clusterer.fit_predict(X)
        silhouette_avg = sklearn.metrics.silhouette_score(X, cluster_labels)
        x.append(i)
        y.append(silhouette_avg)
    matplotlib.pyplot.plot(x,y)

# %%
three_norms_dict = {'vol_num':['Volume 3','Volume 24','Volume 35'], 'norm_text':[vol_3_norm,vol_24_norm,vol_35_norm]}
three_norms_df = pd.DataFrame(three_norms_dict)

# %%
def dropMissing(wordLst, vocab):
    return [w for w in wordLst if w in vocab]

three_norms_df['reduced_tokens'] = three_norms_df['norm_text'].apply(lambda x: dropMissing(x, threeTFVectorizer.vocabulary_.keys()))

# %%
three_norms_df
# Out:
#      vol_num                                          norm_text  \
# 0   Volume 3  [volume, work, marx, engels, cover, period, ma...
# 1  Volume 24  [originally, publish, volksstaat, june, karl, ...
# 2  Volume 35  [publish, german, english, edition, german, ed...
#
#                                       reduced_tokens
# 0  [volume, work, marx, engels, period, march, au...
# 1  [originally, june, karl, marx, engels, russian...
# 2  [german, english, edition, german, edition, ch...

# %%
three_dictionary = gensim.corpora.Dictionary(three_norms_df['reduced_tokens'])
three_corpus = [three_dictionary.doc2bow(text) for text in three_norms_df['reduced_tokens']]

# %%
gensim.corpora.MmCorpus.serialize('three.mm', three_corpus)
three_mm = gensim.corpora.MmCorpus('three.mm')

# %%
three_lda = gensim.models.ldamodel.LdaModel(corpus=three_mm, id2word=three_dictionary, num_topics=16, alpha='auto', eta='auto')

# %%
three_ldaDF = pandas.DataFrame({
        'volme' : three_norms_df['vol_num'],
        'topics' : [three_lda[three_dictionary.doc2bow(l)] for l in three_norms_df['reduced_tokens']]
    })

# %%
#Dict to temporally hold the probabilities
three_topicsProbDict = {i : [0] * len(three_ldaDF) for i in range(three_lda.num_topics)}

#Load them into the dict
for index, topicTuples in enumerate(three_ldaDF['topics']):
    for topicNum, prob in topicTuples:
        three_topicsProbDict[topicNum][index] = prob

#Update the DataFrame
for topicNum in range(three_lda.num_topics):
    three_ldaDF['topic_{}'.format(topicNum)] = three_topicsProbDict[topicNum]

three_ldaDF
# Out:
#        volme                                             topics  topic_0  \
# 0   Volume 3  [(1, 0.12511319), (2, 0.014052974), (8, 0.4951...  0.00000
# 1  Volume 24               [(8, 0.118272975), (11, 0.88007396)]  0.00000
# 2  Volume 35  [(0, 0.036469717), (2, 0.010797994), (3, 0.087...  0.03647
#
#     topic_1   topic_2   topic_3  topic_4   topic_5   topic_6   topic_7  \
# 0  0.125113  0.014053  0.000000   0.0000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000   0.0000  0.000000  0.000000  0.000000
# 2  0.000000  0.010798  0.087223   0.0479  0.066844  0.108944  0.090147
#
#     topic_8   topic_9  topic_10  topic_11  topic_12  topic_13  topic_14  \
# 0  0.495127  0.000000  0.000000  0.333143  0.000000  0.000000  0.010849
# 1  0.118273  0.000000  0.000000  0.880074  0.000000  0.000000  0.000000
# 2  0.000000  0.106949  0.078894  0.000000  0.195866  0.109737  0.035414
#
#    topic_15
# 0  0.000000
# 1  0.000000
# 2  0.010789

# %%
three_ldaDFV = three_ldaDF[['topic_%d' %x for x in range(16)]]
three_ldaDFVisN = three_ldaDF[['volme']]
three_ldaDFVis = three_ldaDFV.to_numpy()
three_ldaDFVisNames = three_ldaDFVisN.to_numpy()
three_ldaDFV
# Out:
#    topic_0   topic_1   topic_2   topic_3  topic_4   topic_5   topic_6  \
# 0  0.00000  0.125113  0.014053  0.000000   0.0000  0.000000  0.000000
# 1  0.00000  0.000000  0.000000  0.000000   0.0000  0.000000  0.000000
# 2  0.03647  0.000000  0.010798  0.087223   0.0479  0.066844  0.108944
#
#     topic_7   topic_8   topic_9  topic_10  topic_11  topic_12  topic_13  \
# 0  0.000000  0.495127  0.000000  0.000000  0.333143  0.000000  0.000000
# 1  0.000000  0.118273  0.000000  0.000000  0.880074  0.000000  0.000000
# 2  0.090147  0.000000  0.106949  0.078894  0.000000  0.195866  0.109737
#
#    topic_14  topic_15
# 0  0.010849  0.000000
# 1  0.000000  0.000000
# 2  0.035414  0.010789

# %%
N = 3
ind = np.arange(N)
K = three_lda.num_topics  # N documents, K topics
ind = np.arange(N)  # the x-axis locations for the novels
width = 0.5  # the width of the bars
plots = []
height_cumulative = np.zeros(N)

for k in range(K):
    color = plt.cm.coolwarm(k/K, 1)
    if k == 0:
        p = plt.bar(ind, three_ldaDFVis[:, k], width, color=color)
    else:
        p = plt.bar(ind, three_ldaDFVis[:, k], width, bottom=height_cumulative, color=color)
    height_cumulative += three_ldaDFVis[:, k]
    plots.append(p)
    

plt.ylim((0, 1))  # proportions sum to 1, so the height of the stacked bars is 1
plt.ylabel('Topics')

plt.title('Distribution of n=16 Topics Across Young/Middle/Mature Marx')
plt.xticks(ind+width/2, three_ldaDFVisNames, rotation='vertical')

plt.yticks(np.arange(0, 1, 10))
topic_labels = ['Topic #{}'.format(k) for k in range(K)]
plt.legend([p[0] for p in plots], topic_labels, loc='center left', frameon=True,  bbox_to_anchor = (1, .5))

plt.rcParams["figure.figsize"] = (12,5)
plt.show()

#TOPIC 1, TOPIC 8, TOPIC 11

# %%
topicsDict = {}
for topicNum in range(three_lda.num_topics):
    topicWords = [w for w, p in three_lda.show_topic(topicNum)]
    topicsDict['Topic_{}'.format(topicNum)] = topicWords

three_wordRanksDF = pandas.DataFrame(topicsDict)
three_wordRanksDF
# Out:
#    Topic_0     Topic_1   Topic_2  Topic_3  Topic_4  Topic_5  Topic_6  \
# 0     work        work      work   labour     work     work     work
# 1   labour      labour    labour     work     time   labour   labour
# 2     hour        time     value    value   labour     hour     hour
# 3  factory     factory       day     hour     hour     time     time
# 4     time      report      hour     time    value  capital   report
# 5    money        hour   factory   report      day  factory      day
# 6   report     capital      time  factory   report      day    value
# 7  capital  production       man      day  factory      man    child
# 8    value         man    report    money      act    money  factory
# 9    child       value  labourer  capital      man    child    money
#
#      Topic_7     Topic_8  Topic_9 Topic_10 Topic_11 Topic_12 Topic_13  \
# 0     labour        work   labour     work     work     work   labour
# ...

# %%
numCategories = 16

threeKM16 = sklearn.cluster.KMeans(n_clusters = numCategories, init='k-means++')
threeKM16.fit(threeTFVects)
colors = list(plt.cm.rainbow(np.linspace(0,1, numCategories)))
colors_p = [colors[l] for l in threeKM16.labels_]

terms = threeTFVectorizer.get_feature_names()
print("Top terms per cluster:")
order_centroids = threeKM16.cluster_centers_.argsort()[:, ::-1]
for i in range(numCategories):
    print("Cluster %d:" % i)
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind])
    print('\n')

components = threepca.components_
keyword_ids = list(set(order_centroids[:,:10].flatten())) #Get the ids of the most distinguishing words(features) from your kmeans model.
words = [terms[i] for i in keyword_ids]#Turn the ids into words.
x = components[:,keyword_ids][0,:] #Find the coordinates of those words in your biplot.
y = components[:,keyword_ids][1,:]


fig = plt.figure(figsize = (16,9))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
ax.scatter(three_reduced_data[:, 0], three_reduced_data[:, 1], color = colors_p, alpha = 0.5, label = colors)
for i, word in enumerate(words):
    ax.annotate(word, (x[i],y[i]))
plt.xticks(())
plt.yticks(())
plt.title('BiPlot')
plt.show()
# Out:
# Top terms per cluster:
# Cluster 0:
#  law
#  labor
#  humanity
#  french
#  proceeds
#  girls
#  stoves
#  transcribed
#  france
#  du
#
#
# Cluster 1:
#  labour
#  day
#  power
#  division
#  hours
#  working
#  children
#  wages
#  capital
#  surplus
#
#
# Cluster 2:
#  london
#  report
#  14
#  employment
#  children
#  13
#  commission
#  1860
#  air
#  sept
#
#
# Cluster 3:
#  31st
#  reports
#  october
#  oct
#  1848
#  1862
#  1864
#  pp
#  1859
#  1849
#
#
# Cluster 4:
#  work
#  night
#  children
#  hours
#  hour
#  week
#  prescribed
#  time
#  10
#  come
#
#
# Cluster 5:
#  money
#  time
#  commodity
#  master
#  commodities
#  flesh
#  circulation
#  gold
#  labour
#  blood
#
#
# Cluster 6:
#  act
#  factory
#  acts
#  protection
#  phrase
#  parliament
#  working
#  time
#  constitute
#  greatly
#
#
# Cluster 7:
#  english
#  pp
#  people
#  working
#  state
#  trade
#  class
#  great
#  society
#  england
#
#
# Cluster 8:
#  hours
#  day
#  12
#  work
#  14
#  10
# ...

# %%
three_marx_sents_df
# Out:
#          vol_name                                          src_name  \
# 40122    Volume 3                                           Preface
# 40123    Volume 3                                           Preface
# 40124    Volume 3                                           Preface
# 40125    Volume 3                                           Preface
# 40126    Volume 3                                           Preface
# ...           ...                                               ...
# 682403  Volume 35  Chapter XXXIII The Modern Theory of Colonisation
# 682404  Volume 35  Chapter XXXIII The Modern Theory of Colonisation
# 682405  Volume 35  Chapter XXXIII The Modern Theory of Colonisation
# 682406  Volume 35                                     Erwin Marquit
# 682407  Volume 35                                     Erwin Marquit
#
#                                            tokenized_sent  \
# 40122   ['The', 'third', 'volume', 'of', 'the', 'works...
# ...

# %%
print("Homogeneity: {:0.3f}".format(sklearn.metrics.homogeneity_score(three_marx_sents_df['vol_name'], threeKM16.labels_)))
print("Completeness: {:0.3f}".format(sklearn.metrics.completeness_score(three_marx_sents_df['vol_name'], threeKM16.labels_)))
print("V-measure: {:0.3f}".format(sklearn.metrics.v_measure_score(three_marx_sents_df['vol_name'], threeKM16.labels_)))
print("Adjusted Rand Score: {:0.3f}".format(sklearn.metrics.adjusted_rand_score(three_marx_sents_df['vol_name'], threeKM16.labels_)))
# Out:
# Homogeneity: 0.102
# Completeness: 0.029
# V-measure: 0.046
# Adjusted Rand Score: -0.069

# %% [markdown]
# Experiment F: Ripped from Week 8 HW

# %% [markdown]
# Experiment G: Chatbot

# %%
from transformers import AutoModelWithLMHead, AutoTokenizer

tokenizer_marx = AutoTokenizer.from_pretrained("gpt_marx_save")
model_marx = AutoModelWithLMHead.from_pretrained("gpt_marx_save")

# %%
sequence = "Labour"

input = tokenizer_marx.encode(sequence, return_tensors="pt")
generated = model_marx.generate(input, max_length=50, bos_token_id=1, pad_token_id=1, eos_token_ids=1)

resulting_string = tokenizer_marx.decode(generated.tolist()[0])
print(resulting_string)
# Out:
# Labour
# "The Factory Acts were passed between 1836 and 1858"
# "The latter two Acts were mainly aimed at encouraging the employment of young persons and women"
# "The first Act restricted the hours of labour c. 2 and 3 while

# %%
sequence = "Labour is"

input = tokenizer_marx.encode(sequence, return_tensors="pt")
generated = model_marx.generate(input, max_length=50, bos_token_id=1, pad_token_id=1, eos_token_ids=1)

resulting_string = tokenizer_marx.decode(generated.tolist()[0])
print(resulting_string)
# Out:
# Labour is a party of the bourgeoisie"
# "The working class is the whole class the working class is the working class the working class is the revolutionary mass"
# "Hence the phrase 'the working class is a mass of the working class and

# %%
sequence = "In history, labour"

input = tokenizer_marx.encode(sequence, return_tensors="pt")
generated = model_marx.generate(input, max_length=50, bos_token_id=1, pad_token_id=1, eos_token_ids=1)

resulting_string = tokenizer_marx.decode(generated.tolist()[0])
print(resulting_string)
# Out:
# In history, labour is the most essential and the only real form of capital"
# "It is the only form of capital that can be maintained by the proletariat"
# "It is the only form of capital that can be maintained by the bourgeoisie"

# %%
sequence = "The definition of labour is"

input = tokenizer_marx.encode(sequence, return_tensors="pt")
generated = model_marx.generate(input, max_length=50, bos_token_id=1, pad_token_id=1, eos_token_ids=1)

resulting_string = tokenizer_marx.decode(generated.tolist()[0])
print(resulting_string)
# Out:
# The definition of labour is the same in all branches of industry"
# "The same system prevails in glass works"
# "The glass manufacturer is not only a capitalist but also a manufacturer of handicrafts"
# "The same system obtains

# %%
sequence = "Labour is always"

input = tokenizer_marx.encode(sequence, return_tensors="pt")
generated = model_marx.generate(input, max_length=50, bos_token_id=1, pad_token_id=1, eos_token_ids=1)

resulting_string = tokenizer_marx.decode(generated.tolist()[0])
print(resulting_string)
# Out:
# Labour is always in a position to demand that the working day for children be 10 hours on day out from 9 a.m. to 5 p.m."
# "Reports c. for 31st October 1862 p. 56"
# "Thus e
